# %%
import pandas as pd
from glob import glob
# glob 모듈로 많은 파일을 쉽게 읽음

# %%
glob('../data/지역*.xls')
# Out:
# ['../data\\지역_위치별(주유소) (1).xls',
#  '../data\\지역_위치별(주유소) (2).xls',
#  '../data\\지역_위치별(주유소) (3).xls',
#  '../data\\지역_위치별(주유소) (4).xls',
#  '../data\\지역_위치별(주유소) (5).xls',
#  '../data\\지역_위치별(주유소) (6).xls',
#  '../data\\지역_위치별(주유소) (7).xls',
#  '../data\\지역_위치별(주유소).xls']

# %%
station_files = glob('../data/지역*.xls')
station_files
# Out:
# ['../data\\지역_위치별(주유소) (1).xls',
#  '../data\\지역_위치별(주유소) (2).xls',
#  '../data\\지역_위치별(주유소) (3).xls',
#  '../data\\지역_위치별(주유소) (4).xls',
#  '../data\\지역_위치별(주유소) (5).xls',
#  '../data\\지역_위치별(주유소) (6).xls',
#  '../data\\지역_위치별(주유소) (7).xls',
#  '../data\\지역_위치별(주유소).xls']

# %%
tmp_raw = []
for file_name in station_files:
    tmp = pd.read_excel(file_name, header=2)
    tmp_raw.append(tmp)
station_raw = pd.concat(tmp_raw)    
# 8개 엑셀파일을 하나로 합침

# %%
station_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 367 entries, 0 to 25
# Data columns (total 10 columns):
# 지역       367 non-null object
# 상호       367 non-null object
# 주소       367 non-null object
# 상표       367 non-null object
# 전화번호     367 non-null object
# 셀프여부     367 non-null object
# 고급휘발유    367 non-null object
# 휘발유      367 non-null object
# 경유       367 non-null object
# 실내등유     367 non-null object
# dtypes: object(10)
# memory usage: 31.5+ KB

# %%
station_raw.head()
# Out:
#       지역       상호                       주소      상표          전화번호 셀프여부 고급휘발유  \
# 0  대구광역시    그린주유소     대구 달서구 구마로 230 (송현동)   알뜰주유소  053-624-5145    Y     -
# 1  대구광역시  국가대표주유소           대구 달서구 당산로 104   SK에너지  053-626-8778    Y     -
# 2  대구광역시    월드주유소  대구 달서구 달구벌대로 1653 (감삼동)   S-OIL  053-551-8113    N     -
# 3  대구광역시    극동주유소   대구 달서구 야외음악당로 83 (성당동)   S-OIL  053-625-4001    Y     -
# 4  대구광역시    웰컴주유소  대구 달서구 달구벌대로 1536 (감삼동)  현대오일뱅크  053-562-4442    N  1665
#
#     휘발유    경유  실내등유
# 0  1345  1245   925
# 1  1345  1239  1000
# 2  1345  1245     -
# 3  1349  1249   925
# 4  1349  1249  1000

# %%
stations = pd.DataFrame({'Oil_store':station_raw['상호'],
                         '주소':station_raw['주소'],
                         '가격':station_raw['휘발유'],
                         '셀프':station_raw['셀프여부'],
                         '상표':station_raw['상표']})
stations.head()
# Out:
#   Oil_store                       주소    가격 셀프      상표
# 0     그린주유소     대구 달서구 구마로 230 (송현동)  1345  Y   알뜰주유소
# 1   국가대표주유소           대구 달서구 당산로 104  1345  Y   SK에너지
# 2     월드주유소  대구 달서구 달구벌대로 1653 (감삼동)  1345  N   S-OIL
# 3     극동주유소   대구 달서구 야외음악당로 83 (성당동)  1349  Y   S-OIL
# 4     웰컴주유소  대구 달서구 달구벌대로 1536 (감삼동)  1349  N  현대오일뱅크

# %%
stations['구'] = [eachAddress.split()[1] for eachAddress in stations['주소']]
stations.head()
# 주소에서 2번째 문장을 split함
# Out:
#   Oil_store                       주소    가격 셀프      상표    구
# 0     그린주유소     대구 달서구 구마로 230 (송현동)  1345  Y   알뜰주유소  달서구
# 1   국가대표주유소           대구 달서구 당산로 104  1345  Y   SK에너지  달서구
# 2     월드주유소  대구 달서구 달구벌대로 1653 (감삼동)  1345  N   S-OIL  달서구
# 3     극동주유소   대구 달서구 야외음악당로 83 (성당동)  1349  Y   S-OIL  달서구
# 4     웰컴주유소  대구 달서구 달구벌대로 1536 (감삼동)  1349  N  현대오일뱅크  달서구

# %%
stations['구'].unique()
# unique함수를 사용하여 많은자료를 다 보지않고 확인함
# Out:
# array(['달서구', '달성군', '동구', '북구', '서구', '수성구', '중구', '남구'], dtype=object)

# %%
stations[stations['가격']=='-']
# 가격이 기록되지않음(-) 찾기
# Out:
#    Oil_store                        주소 가격 셀프      상표    구
# 54     기지주유소             대구 동구 입석동 675  -  N   GS칼텍스   동구
# 68     대우주유소  대구광역시 북구  원대로 52 (고성동3가)  -  N  현대오일뱅크   북구
# 36     달서주유소      대구 서구 달서천로 176 (평리동)  -  N   S-OIL   서구
# 37     태양주유소           대구 서구 국채보상로 372  -  N  현대오일뱅크   서구
# 48    대자연주유소    대구광역시 수성구  파동로 42 (파동)  -  N   SK에너지  수성구

# %%
stations = stations[stations['가격']!='-']
stations.head()
# Out:
#   Oil_store                       주소    가격 셀프      상표    구
# 0     그린주유소     대구 달서구 구마로 230 (송현동)  1345  Y   알뜰주유소  달서구
# 1   국가대표주유소           대구 달서구 당산로 104  1345  Y   SK에너지  달서구
# 2     월드주유소  대구 달서구 달구벌대로 1653 (감삼동)  1345  N   S-OIL  달서구
# 3     극동주유소   대구 달서구 야외음악당로 83 (성당동)  1349  Y   S-OIL  달서구
# 4     웰컴주유소  대구 달서구 달구벌대로 1536 (감삼동)  1349  N  현대오일뱅크  달서구

# %%
stations['가격'] = [float(value) for value in stations['가격']]
# 가격의 type을 float(소수)로 변경

# %%
stations.reset_index(inplace=True)
del stations['index']
# 8개의 엑셀을 합쳤기 때문에 index 초기화하고 중복될 수 있어 제거

# %%
stations.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 362 entries, 0 to 361
# Data columns (total 6 columns):
# Oil_store    362 non-null object
# 주소           362 non-null object
# 가격           362 non-null float64
# 셀프           362 non-null object
# 상표           362 non-null object
# 구            362 non-null object
# dtypes: float64(1), object(5)
# memory usage: 17.0+ KB

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import platform

path = "c:/Windows/Fonts/malgun.ttf"
from matplotlib import font_manager, rc
if platform.system() == 'Windows':
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
# matplotlib 한글문제 해결

# %%
stations.boxplot(column='가격', by='셀프', figsize=(12,8));
# 셀프주유소가 정말 싼 지 확인

# %%
plt.figure(figsize=(12,8))
sns.boxplot(x="상표", y="가격", hue="셀프", data=stations, palette="Set3")
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.boxplot(x="상표", y="가격", data=stations, palette="Set3")
sns.swarmplot(x="상표", y="가격", data=stations, color=".6")
plt.show()
# boxplot과 swarmplot으로 표현

# %%
import json
import folium
import googlemaps
import warnings
warnings.simplefilter(action="ignore", category=FutureWarning)
#warnings.simplefilter(action="ignore", category=FutureWarning) = 경고 무시

# %%
stations.sort_values(by='가격', ascending=False).head(10)
# 휘발유 가격이 비싼 순서대로 정렬
# Out:
#        Oil_store                        주소      가격 셀프      상표    구
# 277     서대구공단주유소       대구 서구 와룡로 358 (중리동)  1657.0  N   GS칼텍스   서구
# 335        조양주유소    대구 중구 달구벌대로 2194 (남산동)  1619.0  N   SK에너지   중구
# 59       공단제일주유소     대구 달서구 달서대로 455 (호산동)  1509.0  N   SK에너지  달서구
# 173        문화주유소     대구 동구 동부로30길 90 (신천동)  1499.0  N   GS칼텍스   동구
# 241  KK(주) 침산주유소       대구 북구 노원로 255 (침산동)  1479.0  N   SK에너지   북구
# 172       반야월주유소      대구 동구 반야월로 199 (동호동)  1459.0  N   S-OIL   동구
# 171        동원주유소       대구 동구 팔공로 192 (봉무동)  1458.0  N   GS칼텍스   동구
# 57   구마선Self오일뱅크  대구광역시 달서구  월배로 255 (상인동)  1449.0  Y  현대오일뱅크  달서구
# 56         명종주유소          대구 달서구 월곡로 134-1  1449.0  N   GS칼텍스  달서구
# 58       대림공단주유소     대구 달서구 달서대로 403 (호림동)  1449.0  N   GS칼텍스  달서구

# %%
stations.sort_values(by='가격', ascending=True).head(10)
# 휘발유 가격이 싼 순서대로 정렬
# Out:
#           Oil_store                         주소      가격 셀프      상표    구
# 61        옥포농협클린주유소        대구 달성군 옥포면 비슬로 2259  1325.0  N  NH-OIL  달성군
# 60        국가대표제3주유소        대구 달성군 옥포면 비슬로 2165  1325.0  Y   SK에너지  달성군
# 120        동대구고속주유소     대구광역시 동구 동촌로 358 (용계동)  1333.0  N   SK에너지   동구
# 242         영신제2주유소     대구 서구 서대구로 207,  (평리동)  1333.0  Y   알뜰주유소   서구
# 243           영신주유소       대구 서구 서대구로 210 (평리동)  1333.0  Y   알뜰주유소   서구
# 244        (주)세아에너지       대구 서구 서대구로 105 (평리동)  1334.0  Y   S-OIL   서구
# 62            부성주유소        대구 달성군 옥포면 비슬로 1901  1335.0  N   S-OIL  달성군
# 121  (주)세아에너지 미니주유소    대구광역시 동구  해동로 171 (검사동)  1335.0  N   S-OIL   동구
# 245           광명주유소   대구광역시 서구  서대구로 201 (평리동)  1338.0  N   GS칼텍스   서구
# 336        (주)한국에너지  대구광역시 남구  두류공원로 103 (대명동)  1339.0  N  현대오일뱅크   남구

# %%
import numpy as np
gu_data = pd.pivot_table(stations, index=["구"], values=["가격"], aggfunc=np.mean)
gu_data.head(10)
# 구별 평균 가격 분석
# Out:
#               가격
# 구
# 남구   1363.615385
# 달서구  1391.166667
# 달성군  1365.983333
# 동구   1375.888889
# 북구   1378.617647
# 서구   1372.361111
# 수성구  1368.458333
# 중구   1394.800000

# %%
geo_path = '../data/05. skorea_municipalities_geo_simple2.json'
geo_data = json.load(open(geo_path, encoding='utf-8'))
map = folium.Map(location=[35.848987 , 128.72818], zoom_start=10.5, tiles='Stamen Toner')
map.choropleth(geo_data = geo_data,
               data = gu_data,
               columns=[gu_data.index, '가격'],
               fill_color='PuRd',
               key_on='feature.id')
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
oil_price_top10 = stations.sort_values(by='가격', ascending=False).head(10)
oil_price_top10
# Out:
#        Oil_store                        주소      가격 셀프      상표    구
# 277     서대구공단주유소       대구 서구 와룡로 358 (중리동)  1657.0  N   GS칼텍스   서구
# 335        조양주유소    대구 중구 달구벌대로 2194 (남산동)  1619.0  N   SK에너지   중구
# 59       공단제일주유소     대구 달서구 달서대로 455 (호산동)  1509.0  N   SK에너지  달서구
# 173        문화주유소     대구 동구 동부로30길 90 (신천동)  1499.0  N   GS칼텍스   동구
# 241  KK(주) 침산주유소       대구 북구 노원로 255 (침산동)  1479.0  N   SK에너지   북구
# 172       반야월주유소      대구 동구 반야월로 199 (동호동)  1459.0  N   S-OIL   동구
# 171        동원주유소       대구 동구 팔공로 192 (봉무동)  1458.0  N   GS칼텍스   동구
# 57   구마선Self오일뱅크  대구광역시 달서구  월배로 255 (상인동)  1449.0  Y  현대오일뱅크  달서구
# 56         명종주유소          대구 달서구 월곡로 134-1  1449.0  N   GS칼텍스  달서구
# 58       대림공단주유소     대구 달서구 달서대로 403 (호림동)  1449.0  N   GS칼텍스  달서구

# %%
oil_price_bottom10 = stations.sort_values(by='가격', ascending=True).head(10)
oil_price_bottom10
# Out:
#           Oil_store                         주소      가격 셀프      상표    구
# 61        옥포농협클린주유소        대구 달성군 옥포면 비슬로 2259  1325.0  N  NH-OIL  달성군
# 60        국가대표제3주유소        대구 달성군 옥포면 비슬로 2165  1325.0  Y   SK에너지  달성군
# 120        동대구고속주유소     대구광역시 동구 동촌로 358 (용계동)  1333.0  N   SK에너지   동구
# 242         영신제2주유소     대구 서구 서대구로 207,  (평리동)  1333.0  Y   알뜰주유소   서구
# 243           영신주유소       대구 서구 서대구로 210 (평리동)  1333.0  Y   알뜰주유소   서구
# 244        (주)세아에너지       대구 서구 서대구로 105 (평리동)  1334.0  Y   S-OIL   서구
# 62            부성주유소        대구 달성군 옥포면 비슬로 1901  1335.0  N   S-OIL  달성군
# 121  (주)세아에너지 미니주유소    대구광역시 동구  해동로 171 (검사동)  1335.0  N   S-OIL   동구
# 245           광명주유소   대구광역시 서구  서대구로 201 (평리동)  1338.0  N   GS칼텍스   서구
# 336        (주)한국에너지  대구광역시 남구  두류공원로 103 (대명동)  1339.0  N  현대오일뱅크   남구

# %%
import googlemaps
gmaps_key = "AIzaSyBuzI1TNKGmJcKylI6yrccddQEczvyvPH0"
gmaps = googlemaps.Client(key=gmaps_key)

# %%
from tqdm import tqdm_notebook

lat = []
lng = []

for n in tqdm_notebook(stations.index):
    try:
        tmp_add = str(stations['주소'][n]).split('(')[0]
        tmp_map = gmaps.geocode(tmp_add)
        tmp_loc = tmp_map[0].get('geometry')
        lat.append(tmp_loc['location']['lat'])
        lng.append(tmp_loc['location']['lng'])
    except:
        lat.append(np.nan)
        lng.append(np.nan)
        print("Here is nan !")
        
stations['lat'] = lat
stations['lng'] = lng
stations
# Out:
# HBox(children=(IntProgress(value=0, max=362), HTML(value='')))
#         Oil_store                           주소      가격 셀프      상표    구  \
# 0           그린주유소         대구 달서구 구마로 230 (송현동)  1345.0  Y   알뜰주유소  달서구
# 1         국가대표주유소               대구 달서구 당산로 104  1345.0  Y   SK에너지  달서구
# 2           월드주유소      대구 달서구 달구벌대로 1653 (감삼동)  1345.0  N   S-OIL  달서구
# 3           극동주유소       대구 달서구 야외음악당로 83 (성당동)  1349.0  Y   S-OIL  달서구
# 4           웰컴주유소      대구 달서구 달구벌대로 1536 (감삼동)  1349.0  N  현대오일뱅크  달서구
# 5         에버그린주유소      대구광역시 달서구  새방로 87 (용산동)  1355.0  Y   S-OIL  달서구
# 6           송현주유소         대구 달서구 구마로 219 (성당동)  1355.0  N   SK에너지  달서구
# 7           대동주유소     대구광역시 달서구  성당로 117 (성당동)  1356.0  N   GS칼텍스  달서구
# 8        하나로Ⅱ 주유소        대구 달서구 비슬로 2682 (대곡동)  1359.0  Y   S-OIL  달서구
# 9          본리동주유소          대구 달서구 구마로 110 (본동)  1365.0  N   GS칼텍스  달서구
# 10         아리랑주유소    대구광역시 달서구  달서대로 696 (신당동)  1365.0  Y   GS칼텍스  달서구
# 11       동마 제1주유소  대구광역시 달서구  달구벌대로 1196 (신당동)  1365.0  Y  현대오일뱅크  달서구
# 12          계명주유소      대구 달서구 달구벌대로 1150 (신당동)  1365.0  N   S-OIL  달서구
# 13          아토주유소        대구광역시 달서구 구마로 42 (본동)  1365.0  Y   S-OIL  달서구
# 14   흥구석유(주)장기주유소      대구 달서구 달구벌대로 1374 (장기동)  1365.0  N   GS칼텍스  달서구
# 15        더진솔한주유소        대구광역시 달서구 용산로 8 (본리동)  1366.0  N  현대오일뱅크  달서구
# 16    계명성서관리공단주유소        대구 달서구 성서로35길 3 (월암동)  1369.0  Y   S-OIL  달서구
# 17       글로벌제3주유소       대구 달서구 앞산순환로 237 (송현동)  1369.0  N   알뜰주유소  달서구
# 18          해원주유소      대구광역시 달서구  구마로 79 (본리동)  1373.0  N   SK에너지  달서구
# 19       남대구IC주유소       대구 달서구 성서공단로 372 (월성동)  1375.0  Y   SK에너지  달서구
# 20          대영주유소         대구 달서구 달서대로 84 (유천동)  1375.0  N   GS칼텍스  달서구
# 21        안국셀프주유소        대구 달서구 성서공단로 329 (장동)  1375.0  Y   SK에너지  달서구
# 22   흥구석유(주)용산주유소          대구 달서구 평리로 78 (용산동)  1377.0  Y   GS칼텍스  달서구
# 23          동서주유소      대구광역시 달서구  구마로 35 (본리동)  1378.0  N   S-OIL  달서구
# 24          효원주유소             대구광역시 달서구 와룡로 76  1379.0  Y   S-OIL  달서구
# 25          에프주유소              대구 달서구 성서동로 184  1379.0  Y   S-OIL  달서구
# 26          창경주유소     대구광역시 달서구  월배로 372 (송현동)  1385.0  Y   GS칼텍스  달서구
# 27         스마일주유소           대구 달서구 월배로 8 (진천동)  1385.0  N   S-OIL  달서구
# 28        서부IC주유소            대구 달서구 달구벌대로 1517  1387.0  N   GS칼텍스  달서구
# 29        본동문화주유소            대구 달서구 와룡로 6 (본동)  1388.0  Y   GS칼텍스  달서구
# ..            ...                          ...     ... ..     ...  ...
# 332  흥구석유(주)동인주유소               대구 중구 동덕로38길 5  1384.0  N   GS칼텍스   중구
# 333       GS태평주유소        대구 중구 태평로 120 (태평로3가)  1395.0  N   GS칼텍스   중구
# 334       달성공원주유소             대구광역시 중구 달성로 115  1397.0  N  현대오일뱅크   중구
# 335         조양주유소       대구 중구 달구벌대로 2194 (남산동)  1619.0  N   SK에너지   중구
# 336      (주)한국에너지    대구광역시 남구  두류공원로 103 (대명동)  1339.0  N  현대오일뱅크   남구
# 337         미니주유소        대구 남구 중앙대로48길 6 (대명동)  1346.0  N  현대오일뱅크   남구
# 338         남산주유소           대구 남구 양지로 32 (대명동)  1347.0  N  현대오일뱅크   남구
# 339         삼성주유소         대구 남구 대봉로 51-3 (봉덕동)  1348.0  N   SK에너지   남구
# 340       처음처럼주유소          대구 남구 성당로 156 (대명동)  1348.0  N   S-OIL   남구
# 341         이천주유소          대구 남구 이천로 119 (이천동)  1349.0  Y   S-OIL   남구
# 342        신대봉주유소          대구 남구 대봉로 112 (이천동)  1349.0  N   SK에너지   남구
# 343   그린에너지 직영주유소      대구광역시 남구  대명로 277 (대명동)  1350.0  Y   S-OIL   남구
# 344        진영 주유소     대구광역시 남구  성당로 296 (대명3동)  1352.0  Y   S-OIL   남구
# 345         도촌주유소         대구 남구 두류공원로 58 (대명동)  1355.0  N   S-OIL   남구
# 346        한마음주유소          대구 남구 대명남로 30 (대명동)  1359.0  Y   SK에너지   남구
# 347        봉덕탑주유소                 대구 남구 봉덕로 31  1359.0  Y   S-OIL   남구
# 348     영남이공대앞주유소      대구광역시 남구  현충로 187 (대명동)  1368.0  N   SK에너지   남구
# 349         삼양주유소          대구 남구 성당로 220 (대명동)  1368.0  N   GS칼텍스   남구
# 350        글로벌주유소     대구광역시 남구  두류공원로 35 (대명동)  1369.0  Y   S-OIL   남구
# 351         삼구주유소         대구 남구 중앙대로 237 (대명동)  1369.0  N   GS칼텍스   남구
# 352         경동주유소           대구 남구 봉덕로 29 (봉덕동)  1369.0  Y   GS칼텍스   남구
# 353         남양주유소           대구 남구 봉덕로 54 (봉덕동)  1369.0  N   SK에너지   남구
# 354         평화주유소           대구 남구 이천로 97 (봉덕동)  1369.0  Y   SK에너지   남구
# 355         자영주유소          대구 남구 현충로 232 (대명동)  1369.0  N   S-OIL   남구
# 356       SK성당주유소          대구 남구 성당로 280 (대명동)  1369.0  N   SK에너지   남구
# 357         도원주유소          대구 남구 명덕로 154 (대명동)  1375.0  Y   S-OIL   남구
# 358     (셀프)엘지주유소     대구광역시 남구 앞산순환로 323 (대명동)  1377.0  Y   GS칼텍스   남구
# 359     SK대구제1주유소          대구 남구 대명로 226 (대명동)  1379.0  Y   SK에너지   남구
# 360         대명주유소       대구광역시 남구  대명로 66 (대명동)  1385.0  N   S-OIL   남구
# 361         매일주유소        대구 남구 현충로 115,  (대명동)  1418.0  N   GS칼텍스   남구
#
#            lat         lng
# 0    35.836763  128.552969
# 1    35.846554  128.545007
# 2    35.854294  128.546700
# 3    35.844634  128.552076
# 4    35.849528  128.535188
# 5    35.865188  128.526257
# 6    35.837458  128.551783
# 7    35.846175  128.565002
# 8    35.807504  128.508976
# 9    35.837070  128.539581
# 10   35.861699  128.492638
# 11   35.851394  128.498381
# 12   35.851074  128.492889
# 13   35.835648  128.551006
# 14   35.849987  128.517842
# 15   35.838053  128.530912
# 16   35.832468  128.506775
# 17   35.824949  128.554395
# 18   35.837741  128.536254
# 19   35.836360  128.523395
# 20   35.815341  128.508466
# 21   35.836909  128.518843
# 22   35.858348  128.532975
# 23   35.837555  128.531443
# 24   35.839426  128.537484
# 25   35.837051  128.513239
# 26   35.827813  128.549468
# 27   35.810839  128.516860
# 28   35.850043  128.532944
# 29   35.833310  128.538311
# ..         ...         ...
# 332  35.871541  128.604884
# 333  35.875651  128.590911
# 334  35.875439  128.581648
# 335  35.862649  128.603229
# 336  35.845674  128.567912
# 337  35.852345  128.591132
# 338  35.850743  128.575503
# 339  35.843123  128.603827
# 340  35.848190  128.569538
# 341  35.851886  128.598185
# 342  35.848546  128.604294
# 343  35.843849  128.586554
# 344  35.859107  128.574816
# 345  35.842860  128.571859
# 346  35.834182  128.561632
# 347  35.845455  128.594115
# 348  35.849369  128.580479
# 349  35.852405  128.574206
# 350  35.840945  128.573408
# 351  35.854569  128.590260
# 352  35.845481  128.593861
# 353  35.844627  128.596710
# 354  35.849658  128.598251
# 355  35.853201  128.583709
# 356  35.857722  128.574752
# 357  35.856375  128.587122
# 358  35.829395  128.562128
# 359  35.840543  128.581792
# 360  35.838868  128.564830
# 361  35.843190  128.579685
#
# [362 rows x 8 columns]

# %%
from tqdm import tqdm_notebook

lat = []
lng = []

for n in tqdm_notebook(oil_price_top10.index):
    try:
        tmp_add = str(oil_price_top10['주소'][n]).split('(')[0]        
        tmp_map = gmaps.geocode(tmp_add)
        tmp_loc = tmp_map[0].get('geometry')        
        lat.append(tmp_loc['location']['lat'])
        lng.append(tmp_loc['location']['lng'])
    except:
        lat.append(np.nan)
        lng.append(np.nan)
        print("Here is nan !")
        
oil_price_top10['lat'] = lat
oil_price_top10['lng'] = lng
oil_price_top10
# 주소에 (를 기준으로 분리해서 GoogleMaps API로 검색하여 가장 비싼 주유소 lat lng 구함
# Out:
# HBox(children=(IntProgress(value=0, max=10), HTML(value='')))
#        Oil_store                        주소      가격 셀프      상표    구        lat  \
# 277     서대구공단주유소       대구 서구 와룡로 358 (중리동)  1657.0  N   GS칼텍스   서구  35.864375
# 335        조양주유소    대구 중구 달구벌대로 2194 (남산동)  1619.0  N   SK에너지   중구  35.862649
# 59       공단제일주유소     대구 달서구 달서대로 455 (호산동)  1509.0  N   SK에너지  달서구  35.840035
# 173        문화주유소     대구 동구 동부로30길 90 (신천동)  1499.0  N   GS칼텍스   동구  35.869074
# 241  KK(주) 침산주유소       대구 북구 노원로 255 (침산동)  1479.0  N   SK에너지   북구  35.901280
# 172       반야월주유소      대구 동구 반야월로 199 (동호동)  1459.0  N   S-OIL   동구  35.872298
# 171        동원주유소       대구 동구 팔공로 192 (봉무동)  1458.0  N   GS칼텍스   동구  35.944391
# 57   구마선Self오일뱅크  대구광역시 달서구  월배로 255 (상인동)  1449.0  Y  현대오일뱅크  달서구  35.820200
# 56         명종주유소          대구 달서구 월곡로 134-1  1449.0  N   GS칼텍스  달서구  35.809109
# 58       대림공단주유소     대구 달서구 달서대로 403 (호림동)  1449.0  N   GS칼텍스  달서구  35.835250
#
#             lng
# 277  128.537903
# 335  128.603229
# 59   128.491519
# 173  128.628990
# 241  128.587847
# 172  128.710251
# 171  128.671877
# 57   128.541018
# 56   128.548146
# 58   128.491297

# %%
lat = []
lng = []

for n in tqdm_notebook(oil_price_bottom10.index):
    try:
        tmp_add = str(oil_price_bottom10['주소'][n]).split('(')[0]
        tmp_map = gmaps.geocode(tmp_add)
        tmp_loc = tmp_map[0].get('geometry')
        lat.append(tmp_loc['location']['lat'])
        lng.append(tmp_loc['location']['lng'])
    except:
        lat.append(np.nan)
        lng.append(np.nan)
        print("Here is nan !")
        
oil_price_bottom10['lat'] = lat
oil_price_bottom10['lng'] = lng
oil_price_bottom10
# 주소에 (를 기준으로 분리해서 GoogleMaps API로 검색하여 가장 비싼 주유소 lat lng 구함
# Out:
# HBox(children=(IntProgress(value=0, max=10), HTML(value='')))
#           Oil_store                         주소      가격 셀프      상표    구  \
# 61        옥포농협클린주유소        대구 달성군 옥포면 비슬로 2259  1325.0  N  NH-OIL  달성군
# 60        국가대표제3주유소        대구 달성군 옥포면 비슬로 2165  1325.0  Y   SK에너지  달성군
# 120        동대구고속주유소     대구광역시 동구 동촌로 358 (용계동)  1333.0  N   SK에너지   동구
# 242         영신제2주유소     대구 서구 서대구로 207,  (평리동)  1333.0  Y   알뜰주유소   서구
# 243           영신주유소       대구 서구 서대구로 210 (평리동)  1333.0  Y   알뜰주유소   서구
# 244        (주)세아에너지       대구 서구 서대구로 105 (평리동)  1334.0  Y   S-OIL   서구
# 62            부성주유소        대구 달성군 옥포면 비슬로 1901  1335.0  N   S-OIL  달성군
# 121  (주)세아에너지 미니주유소    대구광역시 동구  해동로 171 (검사동)  1335.0  N   S-OIL   동구
# 245           광명주유소   대구광역시 서구  서대구로 201 (평리동)  1338.0  N   GS칼텍스   서구
# 336        (주)한국에너지  대구광역시 남구  두류공원로 103 (대명동)  1339.0  N  현대오일뱅크   남구
#
#            lat         lng
# 61   35.789720  128.468323
# 60   35.787875  128.458345
# 120  35.876795  128.678440
# 242  35.876601  128.554507
# 243  35.876662  128.555351
# 244  35.867391  128.554988
# 62   35.780274  128.431935
# 121  35.887487  128.647861
# 245  35.876103  128.554565
# 336  35.845674  128.567912

# %%
stations[stations['Oil_store']=='한국광유(주)청기와주유소']
# Out:
#          Oil_store                    주소      가격 셀프     상표    구        lat  \
# 302  한국광유(주)청기와주유소  대구 수성구 화랑로 222 (만촌동)  1365.0  Y  SK에너지  수성구  35.873002
#
#             lng
# 302  128.653438

# %%
stations.loc[stations['Oil_store']=='한국광유(주)청기와주유소', 'lat']=35.877877
stations[stations['Oil_store']=='한국광유(주)청기와주유소']
# Out:
#          Oil_store                    주소      가격 셀프     상표    구        lat  \
# 302  한국광유(주)청기와주유소  대구 수성구 화랑로 222 (만촌동)  1365.0  Y  SK에너지  수성구  35.877877
#
#             lng
# 302  128.653438

# %%
stations.loc[stations['Oil_store']=='한국광유(주)청기와주유소', 'lng']=128.649463
stations[stations['Oil_store']=='한국광유(주)청기와주유소']
# Out:
#          Oil_store                    주소      가격 셀프     상표    구        lat  \
# 302  한국광유(주)청기와주유소  대구 수성구 화랑로 222 (만촌동)  1365.0  Y  SK에너지  수성구  35.877877
#
#             lng
# 302  128.649463

# %%
map = folium.Map(location=[35.848987 , 128.72818], zoom_start=10.5)

for n in oil_price_top10.index:
    if pd.notnull(oil_price_top10['lat'][n]):
        folium.CircleMarker([oil_price_top10['lat'][n], oil_price_top10['lng'][n]], 
                            radius=30, color='#CD3181', fill_color='#CD3181').add_to(map)
        
for n in oil_price_bottom10.index:
    if pd.notnull(oil_price_bottom10['lat'][n]):
                  folium.CircleMarker([oil_price_bottom10['lat'][n], oil_price_bottom10['lng'][n]],
                            radius=30, color='#3186cc', fill_color='#3186cc').add_to(map)
map                  
# 가장 비싼 10개주유소를 빨간색 가장 싼 10개 주유소를 파란색으로 지도에 표시함
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
geo_path = '../data/05. skorea_municipalities_geo_simple2.json'
geo_data = json.load(open(geo_path, encoding='utf-8'))
map = folium.Map(location=[35.848987 , 128.72818], zoom_start=10.5, tiles='Stamen Toner')
map.choropleth(geo_data = geo_data,
               data = gu_data,
               columns=[gu_data.index, '가격'],
               fill_color='PuRd',
               key_on='feature.id')

for n in oil_price_top10.index:
    folium.Marker([oil_price_top10['lat'][n], oil_price_top10['lng'][n]], popup=oil_price_top10['Oil_store'][n], icon=folium.Icon(color= 'red', icon='info-sign')).add_to(map)
        
for x in oil_price_bottom10.index:    
    folium.Marker([oil_price_bottom10['lat'][x], oil_price_bottom10['lng'][x]], popup=oil_price_bottom10['Oil_store'][x]).add_to(map)
    
map
# 구별 가격과 marker를 이용해 상호명까지 표시
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
geo_path = '../data/05. skorea_municipalities_geo_simple2.json'
geo_data = json.load(open(geo_path, encoding='utf-8'))
map = folium.Map(location=[35.848987 , 128.72818], zoom_start=10.5, tiles='Stamen Toner')
map.choropleth(geo_data = geo_data,
               data = gu_data,
               columns=[gu_data.index, '가격'],
               fill_color='PuRd',
               key_on='feature.id')

for n in stations.index:
    folium.Marker([stations['lat'][n], stations['lng'][n]], popup=stations['Oil_store'][n]).add_to(map)       
    
map
# 주유소가 곳곳에 몰려있어 가격경쟁이 심한 대구
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
