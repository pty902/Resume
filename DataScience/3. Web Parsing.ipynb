# %%
from bs4 import BeautifulSoup

# %%
page = open("../data/03. test_first.html",'r').read()
soup = BeautifulSoup(page, 'html.parser')
print(soup.prettify())
# open('r') = 읽기 옵션
# print(soup.prettify()) = 들여쓰기적용되어 보기좋게 나타냄
# 'html.parser' html 문법규칙으로 내용 해석
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <title>
#    Very Simple HTML Code by PinkWink
#   </title>
#  </head>
#  <body>
#   <div>
#    <p class="inner-text first-item" id="first">
#     Happy PinkWink.
#     <a href="http://www.pinkwink.kr" id="pw-link">
#      PinkWink
#     </a>
#    </p>
#    <p class="inner-text second-item">
#     Happy Data Science.
#     <a href="https://www.python.org" id="py-link">
#      Python
#     </a>
#    </p>
#   </div>
#   <p class="outer-text first-item" id="second">
#    <b>
#     Data Science is funny.
#    </b>
#   </p>
#   <p class="outer-text">
#    <b>
#     All I need is Love.
#    </b>
#   </p>
#  </body>
# </html>

# %%
list(soup.children)
# soup변수 한 단계 아래포함된 태그를 나타냄
# Out:
# ['html', '\n', <html>
#  <head>
#  <title>Very Simple HTML Code by PinkWink</title>
#  </head>
#  <body>
#  <div>
#  <p class="inner-text first-item" id="first">
#                  Happy PinkWink.
#                  <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
#  </p>
#  <p class="inner-text second-item">
#                  Happy Data Science.
#                  <a href="https://www.python.org" id="py-link">Python</a>
#  </p>
#  </div>
#  <p class="outer-text first-item" id="second">
#  <b>
#                  Data Science is funny.
#              </b>
#  </p>
#  <p class="outer-text">
#  <b>
#                  All I need is Love.
#              </b>
#  </p>
#  </body>
#  </html>]

# %%
html = list(soup.children)[2]
html
# Out:
# <html>
# <head>
# <title>Very Simple HTML Code by PinkWink</title>
# </head>
# <body>
# <div>
# <p class="inner-text first-item" id="first">
#                 Happy PinkWink.
#                 <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
# </p>
# <p class="inner-text second-item">
#                 Happy Data Science.
#                 <a href="https://www.python.org" id="py-link">Python</a>
# </p>
# </div>
# <p class="outer-text first-item" id="second">
# <b>
#                 Data Science is funny.
#             </b>
# </p>
# <p class="outer-text">
# <b>
#                 All I need is Love.
#             </b>
# </p>
# </body>
# </html>

# %%
list(html.children)
# Out:
# ['\n', <head>
#  <title>Very Simple HTML Code by PinkWink</title>
#  </head>, '\n', <body>
#  <div>
#  <p class="inner-text first-item" id="first">
#                  Happy PinkWink.
#                  <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
#  </p>
#  <p class="inner-text second-item">
#                  Happy Data Science.
#                  <a href="https://www.python.org" id="py-link">Python</a>
#  </p>
#  </div>
#  <p class="outer-text first-item" id="second">
#  <b>
#                  Data Science is funny.
#              </b>
#  </p>
#  <p class="outer-text">
#  <b>
#                  All I need is Love.
#              </b>
#  </p>
#  </body>, '\n']

# %%
body = list(html.children)[3]
body
# Out:
# <body>
# <div>
# <p class="inner-text first-item" id="first">
#                 Happy PinkWink.
#                 <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
# </p>
# <p class="inner-text second-item">
#                 Happy Data Science.
#                 <a href="https://www.python.org" id="py-link">Python</a>
# </p>
# </div>
# <p class="outer-text first-item" id="second">
# <b>
#                 Data Science is funny.
#             </b>
# </p>
# <p class="outer-text">
# <b>
#                 All I need is Love.
#             </b>
# </p>
# </body>

# %%
soup.body
# Out:
# <body>
# <div>
# <p class="inner-text first-item" id="first">
#                 Happy PinkWink.
#                 <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
# </p>
# <p class="inner-text second-item">
#                 Happy Data Science.
#                 <a href="https://www.python.org" id="py-link">Python</a>
# </p>
# </div>
# <p class="outer-text first-item" id="second">
# <b>
#                 Data Science is funny.
#             </b>
# </p>
# <p class="outer-text">
# <b>
#                 All I need is Love.
#             </b>
# </p>
# </body>

# %%
list(body.children)
# Out:
# ['\n', <div>
#  <p class="inner-text first-item" id="first">
#                  Happy PinkWink.
#                  <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
#  </p>
#  <p class="inner-text second-item">
#                  Happy Data Science.
#                  <a href="https://www.python.org" id="py-link">Python</a>
#  </p>
#  </div>, '\n', <p class="outer-text first-item" id="second">
#  <b>
#                  Data Science is funny.
#              </b>
#  </p>, '\n', <p class="outer-text">
#  <b>
#                  All I need is Love.
#              </b>
#  </p>, '\n']

# %%
soup.find_all('p')
# p 모두 찾음
# Out:
# [<p class="inner-text first-item" id="first">
#                  Happy PinkWink.
#                  <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
#  </p>, <p class="inner-text second-item">
#                  Happy Data Science.
#                  <a href="https://www.python.org" id="py-link">Python</a>
#  </p>, <p class="outer-text first-item" id="second">
#  <b>
#                  Data Science is funny.
#              </b>
#  </p>, <p class="outer-text">
#  <b>
#                  All I need is Love.
#              </b>
#  </p>]

# %%
soup.find('p')
# p 하나만 찾음
# Out:
# <p class="inner-text first-item" id="first">
#                 Happy PinkWink.
#                 <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
# </p>

# %%
soup.find_all('p', class_='outer-text')
# Out:
# [<p class="outer-text first-item" id="second">
#  <b>
#                  Data Science is funny.
#              </b>
#  </p>, <p class="outer-text">
#  <b>
#                  All I need is Love.
#              </b>
#  </p>]

# %%
soup.find_all(class_="outer-text")
# Out:
# [<p class="outer-text first-item" id="second">
#  <b>
#                  Data Science is funny.
#              </b>
#  </p>, <p class="outer-text">
#  <b>
#                  All I need is Love.
#              </b>
#  </p>]

# %%
soup.find_all(id="first")
# Out:
# [<p class="inner-text first-item" id="first">
#                  Happy PinkWink.
#                  <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
#  </p>]

# %%
soup.find('p')
# Out:
# <p class="inner-text first-item" id="first">
#                 Happy PinkWink.
#                 <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
# </p>

# %%
soup.head
# Out:
# <head>
# <title>Very Simple HTML Code by PinkWink</title>
# </head>

# %%
soup.head.next_sibling
# 제일 처음 나타난 태그의 다음것을 찾음
# Out:
# '\n'

# %%
soup.head.next_sibling.next_sibling
# Out:
# <body>
# <div>
# <p class="inner-text first-item" id="first">
#                 Happy PinkWink.
#                 <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
# </p>
# <p class="inner-text second-item">
#                 Happy Data Science.
#                 <a href="https://www.python.org" id="py-link">Python</a>
# </p>
# </div>
# <p class="outer-text first-item" id="second">
# <b>
#                 Data Science is funny.
#             </b>
# </p>
# <p class="outer-text">
# <b>
#                 All I need is Love.
#             </b>
# </p>
# </body>

# %%
body.p
# Out:
# <p class="inner-text first-item" id="first">
#                 Happy PinkWink.
#                 <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
# </p>

# %%
body.p.next_sibling.next_sibling
# Out:
# <p class="inner-text second-item">
#                 Happy Data Science.
#                 <a href="https://www.python.org" id="py-link">Python</a>
# </p>

# %%
for each_tag in soup.find_all('p'):
    print(each_tag.get_text())
# get_text() = 태그 안에 있는 텍스트만 가지고 옴
# Out:
#                 Happy PinkWink.
#                 PinkWink
#
#
#                 Happy Data Science.
#                 Python
#
#
#
#                 Data Science is funny.
#
#
#
#
#                 All I need is Love.

# %%
body.get_text()
# Out:
# '\n\n\n                Happy PinkWink.\n                PinkWink\n\n\n                Happy Data Science.\n                Python\n\n\n\n\n                Data Science is funny.\n            \n\n\n\n                All I need is Love.\n            \n\n'

# %%
links = soup.find_all('a')
links
# Out:
# [<a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>,
#  <a href="https://www.python.org" id="py-link">Python</a>]

# %%
for each in links:
    href = each['href']
    text = each.string
    print(text + ' -> ' + href)
# 텍스트 -> 링크 형식으로 파싱
# Out:
# PinkWink -> http://www.pinkwink.kr
# Python -> https://www.python.org

# %%
from urllib.request import urlopen

# %%
url = "https://finance.naver.com/marketindex/"
page = urlopen(url)
soup = BeautifulSoup(page, "html.parser")
print(soup.prettify())
# Out:
# <script language="javascript" src="/template/head_js.nhn?referer=info.finance.naver.com&amp;menu=marketindex&amp;submenu=market">
# </script>
# <script src="/js/info/jindo.min.ns.1.5.3.euckr.js" type="text/javascript">
# </script>
# <script src="/js/jindo.1.5.3.element-text-patch.js" type="text/javascript">
# </script>
# <div id="container" style="padding-bottom:0px;">
#  <script language="JavaScript" src="/js/flashObject.js?20190125190352">
#  </script>
#  <div class="market_include">
#   <div class="market_data">
#    <div class="market1">
#     <div class="title">
#      <h2 class="h_market1">
#       <span>
#        환전 고시 환율
#       </span>
#      </h2>
#     </div>
#     <!-- data -->
#     <div class="data">
#      <ul class="data_lst" id="exchangeList">
#       <li class="on">
#        <a class="head usd" href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_USDKRW" onclick="clickcr(this, 'fr1.usdt', '', '', event);">
#         <h3 class="h_lst">
# ...

# %%
soup.find_all('span', 'value')[0].string
# Out:
# '1,117.10'

# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen

url_base = 'http://www.chicagomag.com'
url_sub = '/Chicago-Magazine/November-2012/Best-Sandwiches-Chicago/'
url = url_base + url_sub

html = urlopen(url)
soup = BeautifulSoup(html, "html.parser")

soup
# Out:
# <!DOCTYPE doctype html>
#
# <html lang="en">
# <head>
# <!-- Urbis magnitudo. Fabulas magnitudo. -->
# <meta charset="utf-8"/>
# <style>a.edit_from_site {display: none !important;}</style>
# <title>
#   The 50 Best Sandwiches in Chicago |
#   Chicago magazine
#       |  November 2012
#     </title>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable = no" name="viewport">
# <meta content="Our list of Chicago’s 50 best sandwiches, ranked in order of deliciousness" name="description"/>
# <!-- <meta name="description" content="Our list of Chicago’s 50 best sandwiches, ranked in order of deliciousness"> -->
# <meta content="sandwiches, dining" name="keywords"/>
# <meta content="37873197144" property="fb:pages">
# <link href="//www.googletagservices.com" rel="dns-prefetch"/>
# <link href="//ajax.googleapis.com" rel="dns-prefetch"/>
# <link href="//securepubads.g.doubleclick.net" rel="dns-prefetch"/>
# ...

# %%
print(soup.find_all('div', 'sammy'))
# Out:
# [<div class="sammy" style="position: relative;">
# <div class="sammyRank">1</div>
# <div class="sammyListing"><a href="/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Old-Oak-Tap-BLT/"><b>BLT</b><br>
# Old Oak Tap<br>
# <em>Read more</em> </br></br></a></div>
# </div>, <div class="sammy" style="position: relative;">
# <div class="sammyRank">2</div>
# <div class="sammyListing"><a href="/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Au-Cheval-Fried-Bologna/"><b>Fried Bologna</b><br/>
# Au Cheval<br/>
# <em>Read more</em> </a></div>
# </div>, <div class="sammy" style="position: relative;">
# <div class="sammyRank">3</div>
# <div class="sammyListing"><a href="/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Xoco-Woodland-Mushroom/"><b>Woodland Mushroom</b><br/>
# Xoco<br/>
# <em>Read more</em> </a></div>
# </div>, <div class="sammy" style="position: relative;">
# <div class="sammyRank">4</div>
# ...

# %%
len(soup.find_all('div', 'sammy'))
# Out:
# 50

# %%
print(soup.find_all('div', 'sammy')[0])
# Out:
# <div class="sammy" style="position: relative;">
# <div class="sammyRank">1</div>
# <div class="sammyListing"><a href="/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Old-Oak-Tap-BLT/"><b>BLT</b><br>
# Old Oak Tap<br>
# <em>Read more</em> </br></br></a></div>
# </div>

# %%
tmp_one = soup.find_all('div', 'sammy')[0]
type(tmp_one)
# bs4.element.Tag 타입이면 변수에 다시 find find_all 명령 사용가능
# Out:
# bs4.element.Tag

# %%
tmp_one.find(class_='sammyRank')
# Out:
# <div class="sammyRank">1</div>

# %%
tmp_one.find(class_='sammyRank').get_text()
# Out:
# '1'

# %%
tmp_one.find(class_='sammyListing').get_text()
# Out:
# 'BLT\r\nOld Oak Tap\nRead more '

# %%
tmp_one.find('a')['href']
# Out:
# '/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Old-Oak-Tap-BLT/'

# %%
import re
tmp_string = tmp_one.find(class_='sammyListing').get_text()
re.split(('\n|\r\n'), tmp_string)
print(re.split(('\n|\r\n'), tmp_string)[0])
print(re.split(('\n|\r\n'), tmp_string)[1])
# | = or \n 이거나 \r\n이면 분리하라
# Out:
# BLT
# Old Oak Tap

# %%
from urllib.parse import urljoin

rank = []
main_menu = []
cafe_name = []
url_add = []

list_soup = soup.find_all('div', 'sammy')

for item in list_soup:
    rank.append(item.find(class_='sammyRank').get_text())
    tmp_string = item.find(class_='sammyListing').get_text()
    main_menu.append(re.split(('\n|\r\n'), tmp_string)[0])
    cafe_name.append(re.split(('\n|\r\n'), tmp_string)[1])
    url_add.append(urljoin(url_base, item.find('a')['href']))
# urljoin을 사용하면 절대경로는 그대로 두고 상대경로는 절대경로로 변환함

# %%
rank[:5]
# Out:
# ['1', '2', '3', '4', '5']

# %%
main_menu[:5]
# Out:
# ['BLT', 'Fried Bologna', 'Woodland Mushroom', 'Roast Beef', 'PB&L']

# %%
cafe_name[:5]
# Out:
# ['Old Oak Tap', 'Au Cheval', 'Xoco', 'Al’s Deli', 'Publican Quality Meats']

# %%
url_add[:5]
# Out:
# ['http://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Old-Oak-Tap-BLT/',
#  'http://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Au-Cheval-Fried-Bologna/',
#  'http://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Xoco-Woodland-Mushroom/',
#  'http://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Als-Deli-Roast-Beef/',
#  'http://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Publican-Quality-Meats-PB-L/']

# %%
len(rank), len(main_menu), len(cafe_name), len(url_add)
# Out:
# (50, 50, 50, 50)

# %%
import pandas as pd

data = {'Rank':rank, 'Menu':main_menu, 'Cafe':cafe_name, 'URL':url_add}
df = pd.DataFrame(data)
df.head()
# Out:
#                      Cafe               Menu Rank  \
# 0             Old Oak Tap                BLT    1
# 1               Au Cheval      Fried Bologna    2
# 2                    Xoco  Woodland Mushroom    3
# 3               Al’s Deli         Roast Beef    4
# 4  Publican Quality Meats               PB&L    5
#
#                                                  URL
# 0  http://www.chicagomag.com/Chicago-Magazine/Nov...
# 1  http://www.chicagomag.com/Chicago-Magazine/Nov...
# 2  http://www.chicagomag.com/Chicago-Magazine/Nov...
# 3  http://www.chicagomag.com/Chicago-Magazine/Nov...
# 4  http://www.chicagomag.com/Chicago-Magazine/Nov...

# %%
df = pd.DataFrame(data, columns=['Rank','Cafe','Menu','URL'])
df.head(5)
# 칼럼순서 정렬
# Out:
#   Rank                    Cafe               Menu  \
# 0    1             Old Oak Tap                BLT
# 1    2               Au Cheval      Fried Bologna
# 2    3                    Xoco  Woodland Mushroom
# 3    4               Al’s Deli         Roast Beef
# 4    5  Publican Quality Meats               PB&L
#
#                                                  URL
# 0  http://www.chicagomag.com/Chicago-Magazine/Nov...
# 1  http://www.chicagomag.com/Chicago-Magazine/Nov...
# 2  http://www.chicagomag.com/Chicago-Magazine/Nov...
# 3  http://www.chicagomag.com/Chicago-Magazine/Nov...
# 4  http://www.chicagomag.com/Chicago-Magazine/Nov...

# %%
df.to_csv('../data/03. best_sandwiches_list_chicago.csv', sep=',', encoding='UTF-8')

# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen
import pandas as pd

# %%
df=pd.read_csv('../data/03. best_sandwiches_list_chicago.csv', index_col=0)
df.head()
# Out:
#    Rank                    Cafe               Menu  \
# 0     1             Old Oak Tap                BLT
# 1     2               Au Cheval      Fried Bologna
# 2     3                    Xoco  Woodland Mushroom
# 3     4               Al’s Deli         Roast Beef
# 4     5  Publican Quality Meats               PB&L
#
#                                                  URL
# 0  http://www.chicagomag.com/Chicago-Magazine/Nov...
# 1  http://www.chicagomag.com/Chicago-Magazine/Nov...
# 2  http://www.chicagomag.com/Chicago-Magazine/Nov...
# 3  http://www.chicagomag.com/Chicago-Magazine/Nov...
# 4  http://www.chicagomag.com/Chicago-Magazine/Nov...

# %%
df['URL'][0]
# Out:
# 'http://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Old-Oak-Tap-BLT/'

# %%
html = urlopen(df['URL'][0])
soup_tmp = BeautifulSoup(html, "html.parser")
soup_tmp
# Out:
# <!DOCTYPE doctype html>
#
# <html lang="en">
# <head>
# <!-- Urbis magnitudo. Fabulas magnitudo. -->
# <meta charset="utf-8"/>
# <style>a.edit_from_site {display: none !important;}</style>
# <title>
#   1. Old Oak Tap BLT |
#   Chicago magazine
#       |  November 2012
#     </title>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable = no" name="viewport">
# <meta content="“Truly inspired.”" name="description"/>
# <!-- <meta name="description" content="&#8220;Truly inspired.&#8221;"> -->
# <meta content="" name="keywords"/>
# <meta content="37873197144" property="fb:pages">
# <link href="//www.googletagservices.com" rel="dns-prefetch"/>
# <link href="//ajax.googleapis.com" rel="dns-prefetch"/>
# <link href="//securepubads.g.doubleclick.net" rel="dns-prefetch"/>
# <link href="//media.chicagomag.com" rel="dns-prefetch"/>
# <link href="//ox-d.godengo.com/" rel="dns-prefetch"/>
# <link href="//www.google-analytics.com" rel="dns-prefetch"/>
# ...

# %%
print(soup_tmp.find('p', 'addy'))
# Out:
# <p class="addy">
# <em>$10. 2109 W. Chicago Ave., 773-772-0406, <a href="http://www.theoldoaktap.com/">theoldoaktap.com</a></em></p>

# %%
price_tmp = soup_tmp.find('p', 'addy').get_text()
price_tmp
# Out:
# '\n$10. 2109 W. Chicago Ave., 773-772-0406, theoldoaktap.com'

# %%
price_tmp.split()
# Out:
# ['$10.', '2109', 'W.', 'Chicago', 'Ave.,', '773-772-0406,', 'theoldoaktap.com']

# %%
price_tmp.split()[0]
# Out:
# '$10.'

# %%
price_tmp.split()[0][:-1]
# Out:
# '$10'

# %%
' '.join(price_tmp.split()[1:-2])
# join 두번째부터 맨 마지막에서 3번째까지 합침
# Out:
# '2109 W. Chicago Ave.,'

# %%
price = []
address = []

for n in df.index[:3]:
    html = urlopen(df['URL'][n])
    soup_tmp = BeautifulSoup(html, 'lxml')
    gettings = soup_tmp.find('p', 'addy').get_text()
    price.append(gettings.split()[0][:-1])
    address.append(' '.join(gettings.split()[1:-2]))

# %%
price
# Out:
# ['$10', '$9', '$9.50']

# %%
address
# Out:
# ['2109 W. Chicago Ave.,', '800 W. Randolph St.,', '445 N. Clark St.,']

# %%
from tqdm import tqdm_notebook

price = []
address = []

for n in tqdm_notebook(df.index):
    html = urlopen(df['URL'][n])
    soup_tmp = BeautifulSoup(html, 'lxml')
    gettings = soup_tmp.find('p', 'addy').get_text()
    price.append(gettings.split()[0][:-1])
    address.append(' '.join(gettings.split()[1:-2]))
# 50개 페이지의 데이터를 tqdm모듈으로 상태 진행바를 적용하여 확인하며 파싱함
# Out:
# A Jupyter Widget

# %%
price
# Out:
# ['$10',
#  '$9',
#  '$9.50',
#  '$9.40',
#  '$10',
#  '$7.25',
#  '$16',
#  '$10',
#  '$9',
#  '$17',
#  '$11',
#  '$5.49',
#  '$14',
#  '$10',
#  '$13',
#  '$4.50',
#  '$11.95',
#  '$11.50',
#  '$6.25',
#  '$15',
#  '$5',
#  '$6',
#  '$8',
#  '$5.99',
#  '$7.52',
#  '$11.95',
#  '$7.50',
#  '$12.95',
#  '$7',
#  '$21',
#  '$9.79',
#  '$9.75',
#  '$13',
#  '$7.95',
#  '$9',
#  '$9',
#  '$8',
#  '$8',
#  '$7',
#  '$6',
#  '$7.25',
#  '$11',
#  '$6',
#  '$9',
#  '$5.49',
#  '$8',
#  '$6.50',
#  '$7.50',
#  '$8.75',
#  '$6.85']

# %%
address
# Out:
# ['2109 W. Chicago Ave.,',
#  '800 W. Randolph St.,',
#  '445 N. Clark St.,',
#  '914 Noyes St., Evanston,',
#  '825 W. Fulton Mkt.,',
#  '100 E. Walton',
#  '1639 S. Wabash Ave.,',
#  '2211 W. North Ave.,',
#  '3619 W. North Ave.,',
#  '3267 S. Halsted St.,',
#  '2537 N. Kedzie Blvd.,',
#  'Multiple',
#  '3124 N. Broadway,',
#  '3455 N. Southport Ave.,',
#  '2657 N. Kedzie Ave.,',
#  '1120 W. Grand Ave.,',
#  '1141 S. Jefferson St.,',
#  '333 E. Benton Pl.,',
#  '1411 N. Wells St.,',
#  '1747 N. Damen Ave.,',
#  '3209 W. Irving Park',
#  'Multiple',
#  '5347 N. Clark St.,',
#  '2954 W. Irving Park Rd.,',
#  'Multiple',
#  '191 Skokie Valley Rd., Highland Park,',
#  'Multiple',
#  '1818 W. Wilson Ave.,',
#  '2517 W. Division St.,',
#  '218 W. Kinzie',
#  'Multiple',
#  '1547 N. Wells St.,',
#  '415 N. Milwaukee Ave.,',
#  '1840 N. Damen Ave.,',
#  '1220 W. Webster Ave.,',
#  '5357 N. Ashland Ave.,',
#  '1834 W. Montrose Ave.,',
#  '615 N. State St.,',
#  'Multiple',
# ...

# %%
len(price), len(address), len(df)
# Out:
# (50, 50, 50)

# %%
df['Price'] = price
df['Address'] = address

df = df.loc[:, ['Rank', 'Cafe', 'Menu', 'Price', 'Address']]
df.set_index('Rank', inplace=True)
df.head()
# Out:
#                         Cafe               Menu  Price  \
# Rank
# 1                Old Oak Tap                BLT    $10
# 2                  Au Cheval      Fried Bologna     $9
# 3                       Xoco  Woodland Mushroom  $9.50
# 4                  Al’s Deli         Roast Beef  $9.40
# 5     Publican Quality Meats               PB&L    $10
#
#                        Address
# Rank
# 1        2109 W. Chicago Ave.,
# 2         800 W. Randolph St.,
# 3            445 N. Clark St.,
# 4     914 Noyes St., Evanston,
# 5          825 W. Fulton Mkt.,

# %%
df.to_csv('../data/03. best_sandwiches_list_chicago2.csv', sep=',', encoding='UTF-8')

# %%
import folium
import pandas as pd
import googlemaps
import numpy as np

# %%
df = pd.read_csv('../data/03. best_sandwiches_list_chicago2.csv', index_col=0)
df.head(5)
# Out:
#                         Cafe               Menu  Price  \
# Rank
# 1                Old Oak Tap                BLT    $10
# 2                  Au Cheval      Fried Bologna     $9
# 3                       Xoco  Woodland Mushroom  $9.50
# 4                  Al’s Deli         Roast Beef  $9.40
# 5     Publican Quality Meats               PB&L    $10
#
#                        Address
# Rank
# 1        2109 W. Chicago Ave.,
# 2         800 W. Randolph St.,
# 3            445 N. Clark St.,
# 4     914 Noyes St., Evanston,
# 5          825 W. Fulton Mkt.,

# %%
gmaps_key = "****************************"
gmaps = googlemaps.Client(key=gmaps_key)

# %%
lat = []
lng = []

for n in tqdm_notebook(df.index):
    if df['Address'][n] != 'Multiple':
        target_name = df['Address'][n]+', '+'Cicago'
        gmaps_output = gmaps.geocode(target_name)
        location_output = gmaps_output[0].get('geometry')
        lat.append(location_output['location']['lat'])
        lng.append(location_output['location']['lng'])
    else:
        lat.append(np.nan)
        lng.append(np.nan)
# address가 Multiple이 !=(아니면) target_name에 넣음 
# target_name 주소를 GoogleAPI에서 lat lng를 구하고 예외는 NaN값 처리
# Out:
# A Jupyter Widget

# %%
df['lat'] = lat
df['lng'] = lng
df
# lat lng 칼럼을 새로 만들고 값입력
# Out:
#                                  Cafe  \
# Rank
# 1                         Old Oak Tap
# 2                           Au Cheval
# 3                                Xoco
# 4                           Al’s Deli
# 5              Publican Quality Meats
# 6     Hendrickx Belgian Bread Crafter
# 7                              Acadia
# 8                   Birchwood Kitchen
# 9                      Cemitas Puebla
# 10                               Nana
# 11                          Lula Cafe
# 12                         Ricobene’s
# 13                       Frog n Snail
# 14                   Crosby’s Kitchen
# 15                    Longman & Eagle
# 16                               Bari
# 17                            Manny’s
# 18                             Eggy’s
# 19                      Old Jerusalem
# 20               Mindy’s HotChocolate
# 21                Olga’s Delicatessen
# 22       Dawali Mediterranean Kitchen
# 23                          Big Jones
# ...

# %%
mapping = folium.Map(location=[df['lat'].mean(), df['lng'].mean()], zoom_start=11)
folium.Marker([df['lat'].mean(), df['lng'].mean()], popup='center').add_to(mapping)
mapping
# lat과 lng의 평균값에 마커를찍고 center라고 표시
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
mapping = folium.Map(location=[df['lat'].mean(), df['lng'].mean()], zoom_start=11)
for n in df.index:
    if df['Address'][n] != 'Multiple':
        folium.Marker([df['lat'][n], df['lng'][n]], popup=df['Cafe'][n]).add_to(mapping)
mapping        
# Address가 Multiple이 아니면 lat lng에 마커를 찍고 Cafe(가게명)표시
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
from bs4 import BeautifulSoup
import pandas as pd

# %%
from urllib.request import urlopen

url_base = "https://movie.naver.com"
url_syb = "/movie/sdb/rank/rmovie.nhn?sel=cur&date=20190129"
page = urlopen(url_base+url_syb)
soup = BeautifulSoup(page, "html.parser")
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="http://imgmovie.naver.com/today/naverme/naverme_profile.jpg" property="me2:image">
# <meta content="네이버영화 " property="me2:post_tag">
# <meta content="네이버영화" property="me2:category1"/>
# <meta content="" property="me2:category2"/>
# <meta content="랭킹 : 네이버 영화" property="og:title"/>
# <meta content="영화, 영화인, 예매, 박스오피스 랭킹 정보 제공" property="og:description"/>
# <meta content="article" property="og:type"/>
# <meta content="https://movie.naver.com/movie/sdb/rank/rmovie.nhn?sel=cur&amp;date=20190129" property="og:url"/>
# <meta content="http://static.naver.net/m/movie/icons/OG_270_270.png" property="og:image"/><!-- http://static.naver.net/m/movie/im/navermovie.jpg -->
# <meta content="http://imgmovie.naver.com/today/naverme/naverme_profile.jpg" property="og:article:thumbnailUrl"/>
# ...

# %%
soup.find_all('div', 'tit5')
# tit3(영화제목) find_all 전부 다 찾음
# Out:
# [<div class="tit5">
#  <a href="/movie/bi/mi/basic.nhn?code=171539" title="그린 북">그린 북</a>
#  </div>, <div class="tit5">
#  <a href="/movie/bi/mi/basic.nhn?code=174830" title="가버나움">가버나움</a>
#  </div>, <div class="tit5">
#  <a href="/movie/bi/mi/basic.nhn?code=144318" title="언더독">언더독</a>
#  </div>, <div class="tit5">
#  <a href="/movie/bi/mi/basic.nhn?code=156464" title="보헤미안 랩소디">보헤미안 랩소디</a>
#  </div>, <div class="tit5">
#  <a href="/movie/bi/mi/basic.nhn?code=178434" title="폴란드로 간 아이들">폴란드로 간 아이들</a>
#  </div>, <div class="tit5">
#  <a href="/movie/bi/mi/basic.nhn?code=14450" title="쉰들러 리스트">쉰들러 리스트</a>
#  </div>, <div class="tit5">
#  <a href="/movie/bi/mi/basic.nhn?code=180220" title="러브 유어셀프 인 서울">러브 유어셀프 인 서울</a>
#  </div>, <div class="tit5">
#  <a href="/movie/bi/mi/basic.nhn?code=171725" title="스파이더맨: 뉴 유니버스">스파이더맨: 뉴 유니버스</a>
#  </div>, <div class="tit5">
#  <a href="/movie/bi/mi/basic.nhn?code=172174" title="어느 가족">어느 가족</a>
#  </div>, <div class="tit5">
# ...

# %%
soup.find_all('div','tit5')[0].a.string
# Out:
# '그린 북'

# %%
soup.find_all('td', 'point')[0].string
# Out:
# '9.65'

# %%
date = pd.date_range('2018-10-1', periods=100, freq='D')
date
# Out:
# DatetimeIndex(['2018-10-01', '2018-10-02', '2018-10-03', '2018-10-04',
#                '2018-10-05', '2018-10-06', '2018-10-07', '2018-10-08',
#                '2018-10-09', '2018-10-10', '2018-10-11', '2018-10-12',
#                '2018-10-13', '2018-10-14', '2018-10-15', '2018-10-16',
#                '2018-10-17', '2018-10-18', '2018-10-19', '2018-10-20',
#                '2018-10-21', '2018-10-22', '2018-10-23', '2018-10-24',
#                '2018-10-25', '2018-10-26', '2018-10-27', '2018-10-28',
#                '2018-10-29', '2018-10-30', '2018-10-31', '2018-11-01',
#                '2018-11-02', '2018-11-03', '2018-11-04', '2018-11-05',
#                '2018-11-06', '2018-11-07', '2018-11-08', '2018-11-09',
#                '2018-11-10', '2018-11-11', '2018-11-12', '2018-11-13',
#                '2018-11-14', '2018-11-15', '2018-11-16', '2018-11-17',
#                '2018-11-18', '2018-11-19', '2018-11-20', '2018-11-21',
# ...

# %%
import urllib
from tqdm import tqdm_notebook

movie_date = []
movie_name = []
movie_point = []

for today in tqdm_notebook(date):
    html = "https://movie.naver.com" + "/movie/sdb/rank/rmovie.nhn?sel=cur&date={date}"
    response = urlopen(html.format(date=urllib.parse.quote(today.strftime('%Y%m%d'))))
    soup = BeautifulSoup(response, "html.parser")
    end = len(soup.find_all('td', 'point'))
    movie_date.extend([today for n in range(0, end)])
    movie_name.extend([soup.find_all('div', 'tit5')[n].a.string for n in range(0, end)])
    movie_point.extend([soup.find_all('td', 'point')[n].string for n in range(0, end)])
# date 변수로 날짜를 받아서 그 날짜의 제목과 평점을 구해 리스트에 저장
# Out:
# A Jupyter Widget

# %%
movie = pd.DataFrame({'date':movie_date, 'name':movie_name, 'point':movie_point})
movie['point'] = movie['point'].astype(float)
movie.head()
# point type을 float(소수)로 설정
# Out:
#         date               name  point
# 0 2018-10-01  극장판 헬로카봇 : 백악기 시대   9.24
# 1 2018-10-01              어느 가족   9.23
# 2 2018-10-01             로마의 휴일   9.22
# 3 2018-10-01      카메라를 멈추면 안 돼!   9.22
# 4 2018-10-01                플래툰   9.16

# %%
import numpy as np
movie_unique = pd.pivot_table(movie, index=['name'], aggfunc=np.sum)
movie_best = movie_unique.sort_values(by='point', ascending=False)
movie_best.head()
# name을 index로 point를 np.sum(더하기)함
# point를 기준으로 내림차순으로 정렬
# Out:
#                 point
# name
# 카메라를 멈추면 안 돼!  913.14
# 스타 이즈 본        844.05
# 타샤 튜더          794.82
# 어느 가족          738.48
# 보헤미안 랩소디       670.39

# %%
tmp = movie.query('name == ["보헤미안 랩소디"]')
tmp
# Out:
#            date      name  point
# 1113 2018-10-31  보헤미안 랩소디   9.72
# 1158 2018-11-01  보헤미안 랩소디   9.71
# 1195 2018-11-02  보헤미안 랩소디   9.70
# 1233 2018-11-03  보헤미안 랩소디   9.70
# 1272 2018-11-04  보헤미안 랩소디   9.70
# 1309 2018-11-05  보헤미안 랩소디   9.69
# 1341 2018-11-06  보헤미안 랩소디   9.68
# 1375 2018-11-07  보헤미안 랩소디   9.67
# 1412 2018-11-08  보헤미안 랩소디   9.67
# 1451 2018-11-09  보헤미안 랩소디   9.66
# 1489 2018-11-10  보헤미안 랩소디   9.67
# 1526 2018-11-11  보헤미안 랩소디   9.66
# 1563 2018-11-12  보헤미안 랩소디   9.66
# 1604 2018-11-13  보헤미안 랩소디   9.66
# 1648 2018-11-14  보헤미안 랩소디   9.65
# 1696 2018-11-15  보헤미안 랩소디   9.65
# 1746 2018-11-16  보헤미안 랩소디   9.64
# 1795 2018-11-17  보헤미안 랩소디   9.63
# 1845 2018-11-18  보헤미안 랩소디   9.63
# 1895 2018-11-19  보헤미안 랩소디   9.63
# 1945 2018-11-20  보헤미안 랩소디   9.62
# 1995 2018-11-21  보헤미안 랩소디   9.62
# 2044 2018-11-22  보헤미안 랩소디   9.62
# 2092 2018-11-23  보헤미안 랩소디   9.62
# 2141 2018-11-24  보헤미안 랩소디   9.61
# 2189 2018-11-25  보헤미안 랩소디   9.60
# 2233 2018-11-26  보헤미안 랩소디   9.59
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.figure(figsize=(12,8))
plt.plot(tmp['date'], tmp['point'])
plt.legend(loc='best')
plt.grid()
plt.show()

# %%
movie_pivot = pd.pivot_table(movie, index=["date"], columns=['name'], values=['point'])
movie_pivot.head()
# Out:
#             point                                                              \
# name       120BPM 7년-그들이 없는 언론 8월의 크리스마스 PMC: 더 벙커 강철비 거미줄에 걸린 소녀 걷기왕 걸어도 걸어도
# date
# 2018-10-01    NaN          NaN       NaN       NaN NaN        NaN NaN    8.64
# 2018-10-02    NaN          NaN       NaN       NaN NaN        NaN NaN    8.64
# 2018-10-03    NaN          NaN       NaN       NaN NaN        NaN NaN    8.64
# 2018-10-04    NaN          NaN       NaN       NaN NaN        NaN NaN    8.64
# 2018-10-05    NaN          NaN       NaN       NaN NaN        NaN NaN    8.64
#
#                                ...                                         \
# name        경주 곰돌이 푸 다시 만나 행복해 ... 헝거게임: 캣칭 파이어 헝거게임:모킹제이 헤이트풀8 현기증    협상
# date                           ...
# 2018-10-01 NaN             NaN ...          NaN       NaN   NaN NaN  7.99
# 2018-10-02 NaN             NaN ...          NaN       NaN   NaN NaN  7.97
# 2018-10-03 NaN            9.32 ...          NaN       NaN   NaN NaN  7.95
# ...

# %%
movie_pivot.columns = movie_pivot.columns.droplevel()
# pivot_table의 결과로 붙은 컬럼 제목(point) 정리

# %%
movie_pivot.head()
# Out:
# name        120BPM  7년-그들이 없는 언론  8월의 크리스마스  PMC: 더 벙커  강철비  거미줄에 걸린 소녀  걷기왕  \
# date
# 2018-10-01     NaN           NaN        NaN        NaN  NaN         NaN  NaN
# 2018-10-02     NaN           NaN        NaN        NaN  NaN         NaN  NaN
# 2018-10-03     NaN           NaN        NaN        NaN  NaN         NaN  NaN
# 2018-10-04     NaN           NaN        NaN        NaN  NaN         NaN  NaN
# 2018-10-05     NaN           NaN        NaN        NaN  NaN         NaN  NaN
#
# name        걸어도 걸어도  경주  곰돌이 푸 다시 만나 행복해 ...  헝거게임: 캣칭 파이어  헝거게임:모킹제이  헤이트풀8  \
# date                                     ...
# 2018-10-01     8.64 NaN              NaN ...           NaN        NaN    NaN
# 2018-10-02     8.64 NaN              NaN ...           NaN        NaN    NaN
# 2018-10-03     8.64 NaN             9.32 ...           NaN        NaN    NaN
# 2018-10-04     8.64 NaN             9.17 ...           NaN        NaN    NaN
# ...

# %%
import platform
from matplotlib import font_manager, rc

path = 'c:/Windows/Fonts/malgun.ttf'
if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system... sorry~~~~')
# matplotlib에서의 한글 문제 설정

# %%
movie_pivot.plot(y=['보헤미안 랩소디', '마약왕', '스윙키즈', '언니'],figsize=(12,6))
plt.legend(loc='best')
plt.grid()
plt.show()
